# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ## Importing data from Zenodo

# %% [markdown]
# We are using here data that we directly download from a Zenodo [repository](https://zenodo.org/record/1213207#.XPEnZ9P7TOQ), and which provides the data for [this paper](https://www.mdpi.com/2071-1050/10/4/1134/htm).
#
# First we give the exact address of the dataset:

# %%
zenodo_address = 'https://zenodo.org/record/1213207/files/Geneva_Eur11_TDY_2010_2039.txt'

# %% [markdown]
# Then we import the paper directly from Zenodo:

# %%
data = pd.read_csv(zenodo_address,sep='\s+', skiprows = [0,1,2])

# %%
data
# Out:
#       dm   m   h   G_Dh   G_Bn   Ta   Ts    FF     DD     RH   RR    N
# 0      1   1   1    0.0    0.0 -2.3 -4.2   1.1  281.2   71.3  0.0  4.2
# 1      1   1   2    0.0    0.0 -2.4 -4.3   1.3  244.9   72.1  0.0  4.8
# 2      1   1   3    0.0    0.0 -2.5 -4.3   1.8  223.0   72.8  0.0  5.5
# 3      1   1   4    0.0    0.0 -2.5 -4.4   2.4  211.7   74.9  0.1  6.3
# 4      1   1   5    0.0    0.0 -2.6 -4.5   3.1  205.3   77.0  0.1  7.2
# 5      1   1   6    0.0    0.0 -2.7 -4.6   3.9  201.3   79.2  0.1  8.0
# 6      1   1   7    5.4    0.0 -2.4 -4.3   4.6  198.5   82.3  0.2  8.0
# 7      1   1   8   10.8    0.0 -2.2 -4.1   4.5  200.2   85.3  0.3  8.0
# 8      1   1   9   16.1    0.0 -1.9 -3.8   4.5  201.9   88.1  0.4  8.0
# 9      1   1  10   44.3    0.0 -1.4 -3.3   4.4  203.7   90.0  0.5  8.0
# 10     1   1  11   72.5    0.0 -0.9 -2.7   4.3  205.5   91.6  0.6  8.0
# 11     1   1  12  100.8    0.0 -0.3 -2.2   4.3  207.3   92.9  0.7  8.0
# ...

# %% [markdown]
# And we reproduce one of the plots:

# %%
fig, ax = plt.subplots()
plt.plot(data.groupby('dm').mean().Ta)
ax.set_xlabel('Month')
ax.set_ylabel('Air temperature (C°)')
plt.show()
